# %%
import requests
import json
import time
import pymysql
#from selenium.webdriver import Chrome,ChromeOptions
import traceback
import sys
from selenium import webdriver
from lxml import etree
headers = {
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.70 Safari/537.36'
    }
url1 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/country/ranklist"
r1 = requests.get(url1, headers)
r1 = json.loads(r1.text)
data_all1 = json.loads(r1["data"])
print(data_all1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-3fcc38e35b5e> in <module>
#      14 r1 = requests.get(url1, headers)
#      15 r1 = json.loads(r1.text)
# ---> 16 data_all1 = json.loads(r1["data"])
#      17 print(data_all1)
#
# E:\Anaconda\envs\tf\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
data_all1['areaTree']
# Out:
# [{'name': '中国',
#   'today': {'confirm': 179, 'isUpdated': True},
#   'total': {'nowConfirm': 1330,
#    'confirm': 86839,
#    'suspect': 3,
#    'dead': 4659,
#    'deadRate': '5.37',
#    'showRate': False,
#    'heal': 80850,
#    'healRate': '93.10',
#    'showHeal': True},
#   'children': [{'name': '香港',
#     'today': {'confirm': 133, 'confirmCuts': 0, 'isUpdated': True, 'tip': ''},
#     'total': {'nowConfirm': 1032,
#      'confirm': 2505,
#      'suspect': 0,
#      'dead': 18,
#      'deadRate': '0.72',
#      'showRate': False,
#      'heal': 1455,
#      'healRate': '58.08',
#      'showHeal': True},
#     'children': [{'name': '地区待确认',
#       'today': {'confirm': 133, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 1032,
#        'confirm': 2505,
#        'suspect': 0,
#        'dead': 18,
#        'deadRate': '0.72',
#        'showRate': False,
#        'heal': 1455,
#        'healRate': '58.08',
#        'showHeal': True}}]},
# ...

# %%
updata=data_all1['lastUpdateTime']
updata
# Out:
# '2020-07-26 11:26:05'

# %%
data_all1['chinaAdd']
# Out:
# {'confirm': 179,
#  'heal': 68,
#  'dead': 2,
#  'nowConfirm': 109,
#  'suspect': 1,
#  'nowSevere': 7,
#  'importedCase': 11,
#  'noInfect': 68}

# %%
for city_infos in data_all1['areaTree'][0]['children']:
    print(city_infos["today"]["tip"])
# Out:
# 北京累计报告境外输入确诊病例174例。
# 北京卫健委未明确治愈病例和死亡病例的归属分区，北京分区现有确诊数据暂无法获取。
# 辽宁累计报告境外输入病例33例。
# 广东省累计报告境外输入病例277例。
# 上海累计报告境外输入确诊病例399例。
# 内蒙古自治区累计报告境外输入确诊病例179例。
#
# 山东累计报告境外输入确诊病例36例。
# 四川累计报告62例境外输入病例。
# 天津市累计报告境外输入确诊病例67例。
# 陕西累计报告境外输入确诊病例78例。
# 福建省累计报告境外输入确诊病例69例。
# 云南省累计报告境外输入确诊病例15例。
# 重庆市累计报告境外输入确诊病例7例。
# 浙江累计报告境外输入确诊病例51例。
# 因河北未明确治愈病例归属，将治愈计入地区待确认，现有确诊实为6月10日后各地市累计确诊。
# 江苏累计报告境外输入确诊病例24例。
#
#
# 宁夏累计确诊病例中包含3名境外输入型病例。
# 贵州累计报告境外输入确诊病例1例。
# 黑龙江省累计报告境外输入确诊病例386例。
# 海南省累计报告境外输入确诊病例2例。
# 安徽省累计报告境外输入确诊病例1例。
# 山西省累计报告境外输入确诊病例67例。
#
# 江西累计报告境外输入病例2例。
# 甘肃累计报告境外输入确诊病例75例。
# 吉林累计报告境外输入确诊病例19例。
# 广西累计报告境外输入确诊病例3例。
# 湖南省累计报告境外输入确诊病例1例。
# 河南累计报告3例境外输入型病例。
