# %%
import requests
import json
import time
import pymysql
#from selenium.webdriver import Chrome,ChromeOptions
import traceback
import sys
from selenium import webdriver
from lxml import etree
headers = {
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.70 Safari/537.36'
    }
url1 = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5"
r1 = requests.get(url1, headers)
r1 = json.loads(r1.text)
data_all1 = json.loads(r1["data"])
print(data_all1)
# Out:
# {'lastUpdateTime': '2020-07-26 11:26:05', 'chinaTotal': {'confirm': 86839, 'heal': 80850, 'dead': 4659, 'nowConfirm': 1330, 'suspect': 3, 'nowSevere': 18, 'importedCase': 2045, 'noInfect': 292}, 'chinaAdd': {'confirm': 179, 'heal': 68, 'dead': 2, 'nowConfirm': 109, 'suspect': 1, 'nowSevere': 7, 'importedCase': 11, 'noInfect': 68}, 'isShowAdd': True, 'showAddSwitch': {'all': True, 'confirm': True, 'suspect': True, 'dead': True, 'heal': True, 'nowConfirm': True, 'nowSevere': True, 'importedCase': True, 'noInfect': True}, 'areaTree': [{'name': '中国', 'today': {'confirm': 179, 'isUpdated': True}, 'total': {'nowConfirm': 1330, 'confirm': 86839, 'suspect': 3, 'dead': 4659, 'deadRate': '5.37', 'showRate': False, 'heal': 80850, 'healRate': '93.10', 'showHeal': True}, 'children': [{'name': '香港', 'today': {'confirm': 133, 'confirmCuts': 0, 'isUpdated': True, 'tip': ''}, 'total': {'nowConfirm': 1032, 'confirm': 2505, 'suspect': 0, 'dead': 18, 'deadRate': '0.72', 'showRate': False, 'heal': 1455, 'healRate': '58.08', 'showHeal': True}, 'children': [{'name': '地区待确认', 'today': {'confirm': 133, 'confirmCuts': 0, 'isUpdated': True}, 'total': {'nowConfirm': 1032, 'confirm': 2505, 'suspect': 0, 'dead': 18, 'deadRate': '0.72', 'showRate': False, 'heal': 1455, 'healRate': '58.08', 'showHeal': True}}]}, {'name': '新疆', 'today': {'confirm': 22, 'confirmCuts': 0, 'isUpdated': True, 'tip': ''}, 'total': {'nowConfirm': 137, 'confirm': 213, 'suspect': 0, 'dead': 3, 'deadRate': '1.41', 'showRate': False, 'heal': 73, 'healRate': '34.27', 'showHeal': True}, 'children': [{'name': '乌鲁木齐', 'today': {'confirm': 22, 'confirmCuts': 0, 'isUpdated': True}, 'total': {'nowConfirm': 135, 'confirm': 158, 'suspect': 0, 'dead': 0, 'deadRate': '0.00', 'showRate': False, 'heal': 23, 'healRate': '14.56', 'showHeal': True}}, {'name': '地区待确认', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 1, 'confirm': 1, 'suspect': 0, 'dead': 0, 'deadRate': '0.00', 'showRate': False, 'heal': 0, 'healRate': '0.00', 'showHeal': True}}, {'name': '喀什', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 1, 'confirm': 1, 'suspect': 0, 'dead': 0, 'deadRate': '0.00', 'showRate': False, 'heal': 0, 'healRate': '0.00', 'showHeal': True}}, {'name': '兵团第四师', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 0, 'confirm': 10, 'suspect': 0, 'dead': 1, 'deadRate': '10.00', 'showRate': False, 'heal': 9, 'healRate': '90.00', 'showHeal': True}}, {'name': '吐鲁番', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 0, 'confirm': 3, 'suspect': 0, 'dead': 0, 'deadRate': '0.00', 'showRate': False, 'heal': 3, 'healRate': '100.00', 'showHeal': True}}, {'name': '昌吉州', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 0, 'confirm': 4, 'suspect': 0, 'dead': 0, 'deadRate': '0.00', 'showRate': False, 'heal': 4, 'healRate': '100.00', 'showHeal': True}}, {'name': '第八师石河子', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 0, 'confirm': 4, 'suspect': 0, 'dead': 1, 'deadRate': '25.00', 'showRate': False, 'heal': 3, 'healRate': '75.00', 'showHeal': True}}, {'name': '兵团第九师', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 0, 'confirm': 4, 'suspect': 0, 'dead': 1, 'deadRate': '25.00', 'showRate': False, 'heal': 3, 'healRate': '75.00', 'showHeal': True}}, {'name': '伊犁州', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 0, 'confirm': 18, 'suspect': 0, 'dead': 0, 'deadRate': '0.00', 'showRate': False, 'heal': 18, 'healRate': '100.00', 'showHeal': True}}, {'name': '六师五家渠', 'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False}, 'total': {'nowConfirm': 0, 'confirm': 2, 'suspect': 0, 'dead': 0, 'deadRate': '0.00', 'showRate': False, 'heal': 2, 'healRate': '100.00', 'showHeal': True}}, {'name': '兵团第十二师', 'today': {'confirm': 0, 'confirm ...

# %%
data_all1['areaTree']

# %%
updata=data_all1['lastUpdateTime']
updata
# Out:
# '2020-07-26 11:26:05'

# %%
data_all1['chinaAdd']
# Out:
# {'confirm': 179,
#  'heal': 68,
#  'dead': 2,
#  'nowConfirm': 109,
#  'suspect': 1,
#  'nowSevere': 7,
#  'importedCase': 11,
#  'noInfect': 68}

# %%
for city_infos in data_all1['areaTree'][0]['children']:
    print('tip' in city_infos["today"].keys())
    print("--------------------------------")
    print(city_infos["today"]["tip"])
# Out:
# True
# --------------------------------
#
# True
# --------------------------------
#
# True
# --------------------------------
# 北京累计报告境外输入确诊病例174例。
# 北京卫健委未明确治愈病例和死亡病例的归属分区，北京分区现有确诊数据暂无法获取。
# True
# --------------------------------
# 辽宁累计报告境外输入病例33例。
# True
# --------------------------------
# 广东省累计报告境外输入病例277例。
# True
# --------------------------------
# 上海累计报告境外输入确诊病例399例。
# True
# --------------------------------
# 内蒙古自治区累计报告境外输入确诊病例179例。
# True
# --------------------------------
#
# True
# --------------------------------
# 山东累计报告境外输入确诊病例36例。
# True
# --------------------------------
# 四川累计报告62例境外输入病例。
# True
# --------------------------------
# 天津市累计报告境外输入确诊病例67例。
# True
# --------------------------------
# 陕西累计报告境外输入确诊病例78例。
# True
# --------------------------------
# 福建省累计报告境外输入确诊病例69例。
# True
# --------------------------------
# 云南省累计报告境外输入确诊病例15例。
# True
# --------------------------------
# 重庆市累计报告境外输入确诊病例7例。
# True
# --------------------------------
# 浙江累计报告境外输入确诊病例51例。
# True
# --------------------------------
# 因河北未明确治愈病例归属，将治愈计入地区待确认，现有确诊实为6月10日后各地市累计确诊。
# True
# --------------------------------
# 江苏累计报告境外输入确诊病例24例。
#
# True
# --------------------------------
#
# True
# --------------------------------
# 宁夏累计确诊病例中包含3名境外输入型病例。
# True
# --------------------------------
# 贵州累计报告境外输入确诊病例1例。
# True
# --------------------------------
# 黑龙江省累计报告境外输入确诊病例386例。
# True
# --------------------------------
# 海南省累计报告境外输入确诊病例2例。
# True
# --------------------------------
# 安徽省累计报告境外输入确诊病例1例。
# True
# --------------------------------
# 山西省累计报告境外输入确诊病例67例。
# True
# --------------------------------
#
# True
# --------------------------------
# 江西累计报告境外输入病例2例。
# True
# --------------------------------
# 甘肃累计报告境外输入确诊病例75例。
# True
# --------------------------------
# 吉林累计报告境外输入确诊病例19例。
# True
# --------------------------------
# 广西累计报告境外输入确诊病例3例。
# True
# --------------------------------
# 湖南省累计报告境外输入确诊病例1例。
# True
# --------------------------------
# 河南累计报告3例境外输入型病例。
# True
# --------------------------------
#
# True
# --------------------------------
